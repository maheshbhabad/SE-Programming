# %%
# Program to draw a line using DDA algorithm using 2 points

x1 = int(input("Enter point A-X1 : "))
y1 = int(input("Enter point A-Y1 : "))
x2 = int(input("Enter point B-X2 : "))
y2 = int(input("Enter point B-Y2 : "))
print("\nGiven points are A({},{}) and B({},{})".format(x1,y1,x2,y2))

diff_Y = y2-y1
diff_X = x2-x1
slope_m = (diff_Y)/(diff_X)
print("Slope of line m = {}".format(slope_m))

line_through = 0
#line_through -> tells us from which quadrant line passes or lies.
delta_X = 0
delta_Y = 0
direct_line = 0
#direct_line = 1 -> Line moves from left to right
#direct_line = 2 -> line moves from right to left

#Below is code to tell info about given line projections
if (x1<x2):
    print("Line is increasing from Left to right.")
    direct_line += 1
    if (x1>0 and x2>0 and y1>0 and y2>0):
        line_through += 1
        print("Lines lies in I-Quadrant.")

    elif (x1>0 and y1>0 and x2<0 and y2>0):
        line_through += 2
        print("Line moves from I-Quadrant to II-Quadrant.")

    elif (x1>0 and y1>0 and x2<0 and y2<0):
        line_through += 3
        print("Line moves from I-Quadrant to III-Quadrant.")

    elif (x1>0 and y1>0 and x2<0 and y2<0):
        line_through += 4
        print("Line moves from I-Quadrant to IV-Quadrant.")

    elif (x1<0 and y1>0 and x2<0 and y2>0):
        line_through += 2
        print("Line lies in II-Quadrant.")

    elif (x1<0 and y1>0 and x2>0 and y2>0):
        line_through += 1
        print("Line moves from II-Quadrant to I-Quadrant.")

    elif (x1<0 and y1>0 and x2<0 and y2<0):
        line_through += 3
        print("Line moves from II-Quadrant to III-Quadrant.")

    elif (x1<0 and y1>0 and x2>0 and y2<0):
        line_through += 4
        print("Line moves from II-Quadrant to IV-Quadrant.")

    elif (x1<0 and y1<0 and x2<0 and y2<0):
        line_through += 3
        print("Line lies in III-Quadrant.")

    elif (x1<0 and y1<0 and x2>0 and y2>0):
        line_through += 1
        print("Line moves from III-Quadrant to I-Quadrant.")

    elif (x1<0 and y1<0 and x2<0 and y2>0):
        line_through += 2
        print("Line moves from III-Quadrant to II-Quadrant.")

    elif (x1<0 and y1<0 and x2>0 and y2<0):
        line_through += 4
        print("Line moves from III-Quadrant to IV-Quadrant.")

    elif (x1>0 and y1<0 and x2>0 and y2<0):
        line_through += 4
        print("Line lies in IV-Quadrant.")

    elif (x1>0 and y1<0 and x2>0 and y2>0):
        line_through += 1
        print("Line moves from IV-Quadrant to I-Quadrant.")

    elif (x1>0 and y1<0 and x2<0 and y2>0):
        line_through += 2
        print("Line moves from IV-Quadrant to II-Quadrant.")

    elif (x1>0 and y1<0 and x2<0 and y2<0):
        line_through += 3
        print("Line mvoes from IV-Quadrant to III-Quadrant")

elif (x1>x2):
    print("Line is increasing from Right to left.")
    direct_line =+ 2
    if (x1>0 and x2>0 and y1>0 and y2>0):
        line_through += 1
        print("Lines lies in I-Quadrant.")

    elif (x1>0 and y1>0 and x2<0 and y2>0):
        line_through += 2
        print("Line moves from I-Quadrant to II-Quadrant.")

    elif (x1>0 and y1>0 and x2<0 and y2<0):
        line_through += 3
        print("Line moves from I-Quadrant to III-Quadrant.")

    elif (x1>0 and y1>0 and x2<0 and y2<0):
        line_through += 4
        print("Line moves from I-Quadrant to IV-Quadrant.")

    elif (x1<0 and y1>0 and x2<0 and y2>0):
        line_through += 2
        print("Line lies in II-Quadrant.")

    elif (x1<0 and y1>0 and x2>0 and y2>0):
        line_through += 1
        print("Line moves from II-Quadrant to I-Quadrant.")

    elif (x1<0 and y1>0 and x2<0 and y2<0):
        line_through += 3
        print("Line moves from II-Quadrant to III-Quadrant.")

    elif (x1<0 and y1>0 and x2>0 and y2<0):
        line_through += 4
        print("Line moves from II-Quadrant to IV-Quadrant.")

    elif (x1<0 and y1<0 and x2<0 and y2<0):
        line_through += 3
        print("Line lies in III-Quadrant.")

    elif (x1<0 and y1<0 and x2>0 and y2>0):
        line_through += 1
        print("Line moves from III-Quadrant to I-Quadrant.")

    elif (x1<0 and y1<0 and x2<0 and y2>0):
        line_through += 2
        print("Line moves from III-Quadrant to II-Quadrant.")

    elif (x1<0 and y1<0 and x2>0 and y2<0):
        line_through += 4
        print("Line moves from III-Quadrant to IV-Quadrant.")

    elif (x1>0 and y1<0 and x2>0 and y2<0):
        line_through += 4
        print("Line lies in IV-Quadrant.")

    elif (x1>0 and y1<0 and x2>0 and y2>0):
        line_through += 1
        print("Line moves from IV-Quadrant to I-Quadrant.")

    elif (x1>0 and y1<0 and x2<0 and y2>0):
        line_through += 2
        print("Line moves from IV-Quadrant to II-Quadrant.")

    elif (x1>0 and y1<0 and x2<0 and y2<0):
        line_through += 3
        print("Line mvoes from IV-Quadrant to III-Quadrant")

# Below is comparism of Slope increasing from left to right
if (slope_m < 1 and direct_line == 1 and line_through == 1):
    delta_X = 1
    delta_Y = slope_m
    
elif (slope_m > 1 and direct_line == 1 and line_through == 1):
    delta_X = 1/slope_m
    delta_Y = 1
    
elif (slope_m < 1 and direct_line == 1 and line_through == 2):
    delta_X = -1
    delta_Y = -slope_m
    
elif (slope_m > 1 and direct_line == 1 and line_through == 2):
    delta_X = -1/slope_m
    delta_Y = -1
    
elif (slope_m < 1 and direct_line == 1 and line_through == 3):
    delta_X = 1
    delta_Y = slope_m
    
elif (slope_m > 1 and direct_line == 1 and line_through == 3):
    delta_X = -1/slope_m
    delta_Y = 1
    
elif (slope_m < 1 and direct_line == 1 and line_through == 4):
    delta_X = 1
    delta_Y = -slope_m
    
elif (slope_m > 1 and direct_line == 1 and line_through == 4):
    delta_X = 1/slope_m
    delta_Y = -1
    
# Below is comparism of Slope increasing from right to left
elif (slope_m < 1 and direct_line == 2 and line_through == 1):
    delta_X = -1
    delta_Y = -slope_m
    
elif (slope_m > 1 and direct_line == 2 and line_through == 1):
    delta_X = -1/slope_m
    delta_Y = -1
    
elif (slope_m < 1 and direct_line == 2 and line_through == 2):
    delta_X = -1
    delta_Y = slope_m
    
elif (slope_m > 1 and direct_line == 2 and line_through == 2):
    delta_X = 1/slope_m
    delta_Y = 1
    
elif (slope_m < 1 and direct_line == 2 and line_through == 3):
    delta_X = -1
    delta_Y = -slope_m
    
elif (slope_m > 1 and direct_line == 2 and line_through == 3):
    delta_X = 1/slope_m
    delta_Y = -1
    
elif (slope_m < 1 and direct_line == 2 and line_through == 4):
    delta_X = -1
    delta_Y = slope_m
    
elif (slope_m > 1 and direct_line == 2 and line_through == 4):
    delta_X = -1/slope_m
    delta_Y = 1
    
print("DeltaX = {} and DeltaY = {}".format(delta_X,delta_Y))
print("\n\n (x,y)    X-incremental     Y-incremental         Round_X    Round_Y")

while(x1!=x2 and y1!=y2):
    x1 += delta_X
    y1 += delta_Y
    print("({},{})           {}              {}              {}        {}"
          .format(round(x1-delta_X),round(y1-delta_Y),round(x1,2),round(y1,2),round(x1),round(y1)))
    
print("({},{})           -                -                -         -".format(x2,y2))
# Out:
# Enter point A-X1 : 10
# Enter point A-Y1 : 5
# Enter point B-X2 : 16
# Enter point B-Y2 : 10
#
# Given points are A(10,5) and B(16,10)
# Slope of line m = 0.8333333333333334
# Line is increasing from Left to right.
# Lines lies in I-Quadrant.
# DeltaX = 1 and DeltaY = 0.8333333333333334
#
#
#  (x,y)    X-incremental     Y-incremental         Round_X    Round_Y
# (10,5)           11              5.83              11        6
# (11,6)           12              6.67              12        7
# (12,7)           13              7.5              13        7
# (13,7)           14              8.33              14        8
# (14,8)           15              9.17              15        9
# (15,9)           16              10.0              16        10
# (16,10)           -                -                -         -
